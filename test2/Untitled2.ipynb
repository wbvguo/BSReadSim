# %%
import pandas as pd
import pickle

# %%
working_path = "/home/wbguo/iproject/BS_genotype/simu/sim_PE_125_0.001_0.001_D/"

reads_chr10_file = working_path + "reads.chr10.pkl"
reads_chr10_val_file = working_path + "reads.chr10_values.pkl"
reads_chr10_variant_file = working_path + "reads.chr10_variants.pkl"



with open(reads_chr10_file, "rb") as f:
    reads_chr10 = pickle.load(f)
    
with open(reads_chr10_val_file, "rb") as f:
    reads_chr10_val = pickle.load(f)

with open(reads_chr10_variant_file, "rb") as f:
    reads_chr10_variant = pickle.load(f)

# %%
reads_chr10
# Out:
# {'1': (0, 1.5105251119911242e-28, 0),
#  '4': (1, 0.972794244031479, 0),
#  '5': (0, 0.041908957655872985, 0),
#  '6': (0, 0.00037656803931046713, 0),
#  '8': (0, 6.582626267994032e-38, 0),
#  '11': (1, 1.4415154733728302e-167, 0),
#  '13': (1, 5.514223534392583e-75, 0),
#  '14': (1, 1.5231828680945563e-15, 0),
#  '18': (0, 0.006857721617524838, 0),
#  '19': (0, 0.00017586760013749763, 0),
#  '21': (0, 1.672064621411046e-05, 0),
#  '23': (0, 8.000359026214248e-22, 0),
#  '25': (1, 8.895203108936458e-12, 0),
#  '31': (1, 1.3883811223003646e-07, 0),
#  '33': (1, 7.529012211438095e-21, 0),
#  '38': (0, 0.8865224828325042, 0),
#  '40': (1, 7.44848907626004e-24, 0),
#  '42': (1, 2.5509330425885434e-72, 0),
#  '44': (0, 1.0754742177287223e-20, 0),
#  '50': (0, 3.697100442436577e-70, 0),
#  '51': (0, 6.679973536622168e-37, 0),
#  '53': (1, 1.625540559102996e-11, 0),
#  '55': (0, 1.5832105782813443e-08, 0),
#  '56': (0, 2.3582058958929213e-67, 0),
#  '58': (0, 0.0343275444319733, 0),
# ...

# %%
reads_chr10_val
# Out:
# {'chr10:68670': [0, 51],
#  'chr10:68674': [0, 51],
#  'chr10:68690': [0, 53],
#  'chr10:68691': [54, 0],
#  'chr10:68692': [0, 53],
#  'chr10:68702': [0, 47],
#  'chr10:68705': [48, 0],
#  'chr10:68709': [13, 37],
#  'chr10:68710': [49, 0],
#  'chr10:68711': [40, 9],
#  'chr10:68712': [49, 0],
#  'chr10:68713': [0, 50],
#  'chr10:68717': [49, 0],
#  'chr10:68719': [2, 46],
#  'chr10:68722': [0, 48],
#  'chr10:68723': [46, 0],
#  'chr10:68725': [0, 48],
#  'chr10:68727': [0, 49],
#  'chr10:68728': [1, 48],
#  'chr10:68733': [0, 51],
#  'chr10:68734': [0, 51],
#  'chr10:68740': [0, 51],
#  'chr10:68743': [0, 53],
#  'chr10:68745': [0, 53],
#  'chr10:68749': [0, 52],
#  'chr10:68754': [0, 53],
#  'chr10:68761': [0, 54],
#  'chr10:68763': [46, 7],
#  'chr10:68765': [0, 53],
#  'chr10:68766': [0, 54],
#  'chr10:68771': [51, 0],
#  'chr10:68773': [0, 49],
#  'chr10:68775': [0, 50],
#  'chr10:68776': [36, 14],
#  'chr10:68779': [50, 0],
#  'chr10:68780': [0, 50],
# ...

# %%
reads_chr10_variant
# Out:
# {1167: {'chrom': 'chr10',
#   'pos': 1167,
#   'reference': 'G',
#   'alt': 'A',
#   'heterozygous': '-',
#   'indel': 0,
#   'iupac': ('A',)},
#  2621: {'chrom': 'chr10',
#   'pos': 2621,
#   'reference': 'G',
#   'alt': 'C',
#   'heterozygous': '-',
#   'indel': 0,
#   'iupac': ('C',)},
#  2832: {'chrom': 'chr10',
#   'pos': 2832,
#   'reference': 'A',
#   'alt': 'C',
#   'heterozygous': '-',
#   'indel': 0,
#   'iupac': ('C',)},
#  3901: {'chrom': 'chr10',
#   'pos': 3901,
#   'reference': 'T',
#   'alt': 'G',
#   'heterozygous': '-',
#   'indel': 0,
#   'iupac': ('G',)},
#  4791: {'chrom': 'chr10',
#   'pos': 4791,
#   'reference': 'G',
#   'alt': 'C',
#   'heterozygous': '-',
#   'indel': 0,
#   'iupac': ('C',)},
#  4841: {'chrom': 'chr10',
#   'pos': 4841,
#   'reference': 'C',
#   'alt': '-',
#   'heterozygous': '-',
#   'indel': -1,
#   'iupac': None},
#  4942: {'chrom': 'chr10',
#   'pos': 4942,
#   'reference': 'T',
#   'alt': 'A',
#   'heterozygous': '-',
#   'indel': 0,
# ...

# %%
class A:
    def __init__(self, para1, B)
        pass
    self.varinats = None
    
    def getData(self):
        pass
    def setVariant(B):
        self.varinats = B
    
    
class B:
    def __init__(self, para1, para2):
        pass
    def getData(self):
        pass

# %%
from xxx import A, B

# %%
A = creatObject()
A.setVariants(B)
A.setMethylaiton(C)
A.runSimulate()
