# %%
import sys
sys.path.append('../../Simulate/')

from BSReadSim_queue import BSReadSim

# %%
working_path = "/home/wbguo/iproject/BSReadSim/test/"

# %% [markdown]
# # WGBS

# %% [markdown]
# ## BSB_test

# %%
ref_fasta = working_path + "data/ref/BSB_test.fa"
outdir = working_path + "out/bsb_test/"

# %% [markdown]
# ### new meth_db

# %%
cgmap_file  = working_path + "data/sim/pe_d/sim.CGmap.gz"
asm_file    = working_path + "data/sim/pe_d/sim.asm.gz"
meth_db_path= None

# %%
test_sim = BSReadSim(ref_fasta=ref_fasta, outdir=outdir, overwrite_db=True,
                     cgmap_file=cgmap_file, asm_file=asm_file, meth_db_path = meth_db_path,
                     n_threads=1, num_reads=1000, 
                     verbose =True, shuffle=False, gzip=False)
# Out:
# Initiating experiment...
# Initiating methylation profile...
#
# [Initiating meth_db] for chr10...
# Filling CGmap for chr10... 184989 sites found in CGmap file, among them 0 sites (0.0%) are incompatible...
# Filling ASM for chr10...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [6], in <module>
# ----> 1 test_sim = BSReadSim(ref_fasta=ref_fasta, outdir=outdir, overwrite_db=True,
#       2                      cgmap_file=cgmap_file, asm_file=asm_file, meth_db_path = meth_db_path,
#       3                      n_threads=1, num_reads=1000,
#       4                      verbose =True, shuffle=False, gzip=False)
#
# File ~/iproject/BSReadSim/test/ipynb/../../Simulate/BSReadSim_queue.py:168, in BSReadSim.__init__(self, ref_fasta, outdir, prefix, meth_db_path, asm_file, cgmap_file, cgmap_pool, meth_seed, beta_params, collect_ch, update_boundary, overwrite_db, vcf_file, mut_rate, haplo_mode, seed, mut_indel_frac, indel_ext_prob, insert_mean, insert_std, insert_min, insert_max, read_len, depth, num_reads, propN_cutoff, conversion_rate, overwrite_bed, middle_cuts, cover_uniform, rrbs_uniform, undirectional, pair_end, random_error, error_rate, error_model, qual_uniform, qual_model, is_uniform, gc_bias_file, site_dependency, site_model, cut_site_str, rrbs_model, probe_bed_file, probe_deviation, n_threads, shuffle, gzip, verbose, collect_stats)
#     166 # prepare the methylation reference
#     167 print('Initiating methylation profile...')
# --> 168 self.meth_set   = SetMethylation(ref_dict=self.ref_dict, outdir=outdir,
#     169                                  meth_db_path=meth_db_path,
#     170                                  cgmap_file=cgmap_file, cgmap_pool=cgmap_pool,
#     171                                  asm_file=asm_file,
#     172                                  beta_params=beta_params,
#     173                                  collect_ch=collect_ch,
#     174                                  update_boundary=update_boundary,
#     175                                  overwrite_db=overwrite_db,
#     176                                  verbose=verbose,
#     177                                  seed=meth_seed)
#     178 self.meth_db    = self.meth_set.meth_db
#     179 #self.meth_db.create_share_arr(self.meth_set.arr_max_size)
#     180
#     181 # prepare output
#
# File ~/iproject/BSReadSim/test/ipynb/../../Simulate/SetMethylation.py:79, in SetMethylation.__init__(self, ref_dict, outdir, meth_db_path, cgmap_file, cgmap_pool, beta_params, asm_file, update_boundary, collect_ch, overwrite_db, seed, verbose)
#      77     self.check_meth_db()
#      78 else:
# ---> 79     self.create_meth_db()
#      81 if self.contig_flag and (not self.cgmap_pool) and self.cgmap_file:
#      82     warnings.warn('No Contig in the CGmap file can be found in the reference fasta, please check!')
#
# File ~/iproject/BSReadSim/test/ipynb/../../Simulate/SetMethylation.py:105, in SetMethylation.create_meth_db(self)
#     103 self.init_meth_db(contig_id)
#     104 self.fill_cgmap(contig_id)
# --> 105 self.fill_asm(contig_id)
#     106 self.fill_dist(contig_id)
#     107 self.arr_max_size[0] = max(self.pos_map.shape[0], self.arr_max_size[0])
#
# File ~/iproject/BSReadSim/test/ipynb/../../Simulate/SetMethylation.py:221, in SetMethylation.fill_asm(self, contig_id)
#     219     print(f"Filling ASM for {contig_id}...", end=" ")
#     220 num_asm_pos, num_404_pos = [0,0] # counting
# --> 221 for line in parseASM(self.asm_file, contig_id, collect_ch = self.collect_ch):
#     222     _, base, pos, context, tot_meth, ref_meth, alt_meth = line
#     223     num_asm_pos += 1
#
# File ~/iproject/BSReadSim/test/ipynb/../../Simulate/UtilityFunctions.py:67, in parseASM.__iter__(self)
#      64     break
#      65 # chr, base, pos, context, dinucleotide, meth, snp_pos, REF, ALT, ref_meth, alt_meth, fold_change, pval, comment
#      66 # comment can be meth_count/tot_count;ref_meth_count/ref_tot_count;alt_meth_count/alt_tot_count
# ---> 67 chr_id, base, pos, context, diN, tot_meth, snp_pos, ref, alt, ref_meth, alt_meth, fold_change, p_val, comment = self.process_line(line)
#      68 if chr_id != self.contig_id:
#      69     continue
#
# ValueError: not enough values to unpack (expected 14, got 10)

# %%
test_sim.run()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [7], in <module>
# ----> 1 test_sim.run()
#
# NameError: name 'test_sim' is not defined

# %%
test_sim = BSReadSim(ref_fasta=ref_fasta, outdir=outdir, overwrite_db=True,
                     cgmap_file=cgmap_file, asm_file=asm_file, meth_db_path = meth_db_path,
                     n_threads=4, num_reads=1000, 
                     verbose =True, shuffle=False, gzip=False)

# %%
test_sim.run()

# %% [markdown]
# ### existing meth_db

# %%
cgmap_file  = None
asm_file    = None
meth_db_path= outdir
# it seems provided meth_db_path will not check the asm mode? or cgmap_mode?

# %%
test_sim = BSReadSim(ref_fasta=ref_fasta, outdir=outdir, overwrite_db=True,
                     cgmap_file=cgmap_file, asm_file=asm_file, meth_db_path = meth_db_path,
                     n_threads=4, num_reads=100000, 
                     verbose =True, shuffle=False, gzip=False)

# %%
test_sim.run()

# %% [markdown]
# ## chr21

# %%
ref_fasta= working_path + "data/ref/chr21.fa"
outdir = working_path + "out/chr21/"

# %% [markdown]
# ### new meth_db

# %%
cgmap_file  = None
asm_file    = None
meth_db_path= None

# %%
test_sim = BSReadSim(ref_fasta=ref_fasta, outdir=outdir, overwrite_db=True,
                     cgmap_file=cgmap_file, asm_file=asm_file, meth_db_path = meth_db_path,
                     n_threads=16, num_reads=10**6,
                     verbose =True, shuffle=False, gzip=False)

# %%
test_sim.run()

# %% [markdown]
# ### existing meth_db

# %%
cgmap_file  = None
asm_file    = None
meth_db_path=

# %% [markdown]
# # RRBS

# %% [markdown]
# # TBS
