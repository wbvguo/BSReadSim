# %%
from Bio import SeqIO
from bsbolt.CallMethylation.CallVector import CallMethylationVector

import queue
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [1], in <cell line: 2>()
#       1 from Bio import SeqIO
# ----> 2 from bsbolt.CallMethylation.CallVector import CallMethylationVector
#       4 import queue
#
# ModuleNotFoundError: No module named 'bsbolt'

# %%
bam_file  = "/u/home/w/wbguo/project-pellegrini/BS_genotype/data/WGBS/ERR2359938.sorted.bam"
fasta_file= "/u/home/w/wbguo/project-pellegrini/BS_genotype/data/WGBS/GRCh38_full_analysis_set_plus_decoy_hla.fa"
genome_db = "/u/home/w/wbguo/project-pellegrini/BS_genotype/PGP-UK/idx/bsbolt/"
contig    = "chr21"

# %%
rtn_queue = queue.Queue()

# %%
vector_call = CallMethylationVector(input_file=bam_file, genome_database=genome_db,
                                    contig=contig, return_queue=rtn_queue)

# %%
# take the chr21, construct the numpy array, for each base
# [[DNABERT, context, methylation level]]
# find out the average covarage region 
# take each reads in these region
# X: 3*100 
# Y: 1*100 
#
