# %%
from scipy.stats import beta
import numpy as np

# %%
x = np.random.random(size = 10)

# %%
beta.fit(x)
# Out:
# (0.586385878024313,
#  0.4464198872766727,
#  0.03207422570126042,
#  0.9440488653906975)
