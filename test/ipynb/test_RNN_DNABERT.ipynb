# %%
import sys

module_path = "/home/wbguo/iproject/BSReadSim/test/code/DNABERT/examples/"
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
import torch
import numpy as np
from transformers import BertModel, BertConfig, DNATokenizer
# Out:
# 2023-03-06 16:35:36.681316: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-03-06 16:35:36.681393: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
dir_to_pretrained_model = "/home/wbguo/iproject/BSReadSim/test/code/DNABERT/pretrained/5-new-12w-0/pytorch_model.bin"
config = BertConfig.from_pretrained('https://raw.githubusercontent.com/jerryji1993/DNABERT/master/src/transformers/dnabert-config/bert-config-5/config.json')
tokenizer = DNATokenizer.from_pretrained('dna5')
model = BertModel.from_pretrained(dir_to_pretrained_model, config=config)
# Out:
# ============================================================
# <class 'transformers.tokenization_dna.DNATokenizer'>

# %%
sequence = "AATCTA ATCTAG TCTAGC CTAGCA"
model_input = tokenizer.encode_plus(sequence, add_special_tokens=True, max_length=512)["input_ids"]
model_input = torch.tensor(model_input, dtype=torch.long)
model_input = model_input.unsqueeze(0)   # to generate a fake batch with batch size one

output = model(model_input)

# %%
output[1]
# Out:
# tensor([[-8.7568e-02,  1.5329e-01,  3.7379e-01,  2.4510e-01, -4.7964e-01,
#           3.7222e-01,  2.3349e-01, -1.9678e-02,  1.9487e-01,  3.2600e-02,
#          -1.6051e-01,  1.4068e-01,  2.0277e-01, -1.7763e-01, -1.4669e-01,
#           6.1363e-01,  1.2301e-01, -2.4783e-01, -8.4105e-02, -6.6017e-01,
#           2.1066e-01,  1.9499e-01, -1.1532e-01, -4.9300e-01, -3.2228e-01,
#           3.1397e-01,  8.0878e-02,  8.7736e-02,  4.6228e-02, -1.3936e-01,
#          -1.2954e-01,  4.5067e-01,  1.4983e-01, -4.5212e-01,  1.4594e-01,
#          -3.5402e-01,  1.2542e-01, -5.6773e-01,  1.9209e-01,  1.9136e-01,
#           6.0008e-01,  3.3661e-02, -3.6919e-02, -6.8633e-01, -3.6329e-01,
#          -2.4131e-01,  6.3037e-02,  3.0249e-01, -7.2815e-01, -2.5088e-01,
#           1.0776e-01,  1.2694e-01, -6.3700e-01, -3.5591e-02, -4.2088e-01,
#           9.8859e-02,  2.6308e-01,  3.9884e-01, -5.6178e-02, -3.9592e-01,
#           1.5657e-01,  3.6757e-01,  1.2873e-01,  2.8904e-01, -5.9972e-02,
#          -6.7629e-01, -3.7118e-01, -1.9931e-01, -1.1219e-02, -6.8754e-02,
#          -1.2780e-01,  3.0358e-01, -5.1882e-01,  5.9342e-01, -1.6229e-01,
#          -5.4567e-01,  4.4317e-02, -4.4713e-01,  5.1305e-01,  8.7538e-02,
#          -1.6320e-01,  5.3013e-03,  4.9607e-01,  4.9282e-01,  1.1044e-01,
#          -4.4259e-01, -2.8755e-01,  5.4967e-02, -1.3819e-01,  8.3945e-02,
#           6.5521e-03,  7.5075e-01, -7.5475e-02, -5.1589e-01,  2.4017e-01,
#           6.7902e-01,  4.4834e-01, -2.2446e-01,  5.1648e-01, -3.4772e-01,
#          -4.3625e-01,  2.0027e-01,  3.4197e-01,  5.5291e-01,  1.3672e-01,
#           2.0839e-01,  3.8390e-01, -7.6755e-01, -6.5973e-02, -1.5860e-01,
#           8.9488e-02, -5.2503e-02,  6.5553e-02,  2.2468e-01,  3.3249e-01,
#          -2.1560e-01, -5.4412e-01, -4.4387e-01,  3.5642e-01,  6.7322e-01,
#          -5.6736e-01,  4.3621e-01,  3.3721e-01, -2.0750e-02, -1.4255e-01,
#          -3.1223e-01,  7.4304e-01,  2.5414e-01,  5.7630e-02,  6.3266e-01,
#           4.3053e-02,  3.3820e-01,  3.7017e-02,  2.1625e-01, -6.7261e-01,
#           3.2773e-01,  2.6015e-01, -3.9129e-01, -2.4289e-01,  1.7785e-01,
#          -4.7099e-01,  7.2909e-01,  2.5789e-03, -4.0934e-01, -2.6797e-01,
#          -2.7487e-01, -3.1794e-01,  1.2020e-01,  4.5795e-01,  2.3540e-01,
#          -2.3612e-01,  1.0405e-02,  3.9024e-01, -4.4932e-02,  4.4548e-01,
#           7.6510e-01,  5.1723e-01,  2.7729e-01,  3.3507e-01,  4.2895e-01,
#           3.0863e-01, -5.0943e-01, -4.0822e-01,  6.6555e-02, -2.6832e-02,
#           3.4054e-01,  1.2686e-01,  4.8008e-01, -8.5253e-02, -5.7326e-01,
#          -5.6968e-02, -2.1459e-01,  7.4120e-01, -2.7503e-02, -3.3261e-01,
#           5.0443e-02, -2.2401e-01,  6.6107e-01,  2.1052e-01, -4.7617e-02,
#          -2.2712e-01, -7.5699e-01, -3.9273e-01,  1.4728e-01,  1.4063e-01,
#          -1.8943e-01, -6.3178e-01, -4.0822e-01, -8.1899e-01, -6.2957e-01,
#          -2.3799e-01, -4.4639e-01, -3.7416e-01,  2.8293e-01, -1.3719e-01,
#           3.7091e-01, -1.0805e-01,  1.5441e-01, -4.7267e-01,  5.1829e-02,
#           1.8305e-01,  5.2728e-01,  2.1209e-02, -2.9880e-01, -3.0574e-01,
#          -9.0199e-01,  5.2574e-01,  5.8898e-01,  6.0832e-01, -6.8271e-01,
#          -1.3894e-01,  4.8130e-01,  3.5166e-01,  9.5075e-03,  2.7876e-01,
#           7.2264e-02, -6.8830e-01, -3.3329e-03,  2.1268e-01,  1.9865e-01,
#           1.1907e-01,  6.3465e-01, -1.2803e-01,  2.5201e-01, -4.4450e-01,
#          -4.8227e-02,  7.8629e-01,  3.6466e-01,  3.9354e-01, -2.5582e-01,
#           4.3201e-01,  3.9114e-01,  5.8472e-01,  2.0496e-01, -2.2753e-01,
#           3.9525e-01, -6.0892e-01,  2.3447e-01, -2.3437e-01, -1.1743e-02,
#          -2.5786e-01, -1.0277e-02, -2.0011e-01]], grad_fn=<TanhBackward0>)

# %% [markdown]
# # construct k-mer

# %%
# using jelly fish
# from itertools import product

# base_str = 'AGCTN'
# kmer_list= [''.join(i) for i in product(base_str,  repeat=11)]

# %% [markdown]
# # encode k-mer

# %%
k=11
kmer_fa = f'/home/wbguo/iproject/BSReadSim/test/kmer/{k}mer.fa'

kmer_dict = {}

with open(kmer_fa, 'r') as f:
    while True:
        line1 = int(f.readline().strip()[1:])
        line2 = f.readline().strip()
        
        # embed line2
        model_input = tokenizer.encode_plus(line2, add_special_tokens=True, max_length=512)["input_ids"]
        model_input = torch.tensor(model_input, dtype=torch.long)
        model_input = model_input.unsqueeze(0)   # to generate a fake batch with batch size one
        kmer_vector = np.squeeze(model(model_input)[1])
        kmer_dict[line2] = [kmer_vector, line1]

# %%
import pickle

kmer_dict_pickle = f'/home/wbguo/iproject/BSReadSim/test/kmer/{k}mer.pickle'
with open(kmer_dict_pickle, 'wb') as handle:
    pickle.dump(kmer_dict, handle)
    
# with open('filename.pickle', 'rb') as handle:
#     b = pickle.load(handle)
