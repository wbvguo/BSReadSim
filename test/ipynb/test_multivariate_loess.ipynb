# %%
import statsmodels.api as sm
import numpy as np
import matplotlib.pyplot as plt

# Generate example data
np.random.seed(0)
x = 5 * np.random.rand(40, 2)
y = np.sin(x[:, 0] + x[:, 1])

# Fit the regression model
kr = sm.nonparametric.KernelReg(y, x, 'c', bw='silverman')
z, _ = kr.fit(x)

# Plot the results
plt.scatter(x[:, 0], x[:, 1], c=y)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1612385/2269722414.py in <module>
#       9
#      10 # Fit the regression model
# ---> 11 kr = sm.nonparametric.KernelReg(y, x, 'c', bw='silverman')
#      12 z, _ = kr.fit(x)
#      13
#
# ~/apps/anaconda3/lib/python3.8/site-packages/statsmodels/nonparametric/kernel_regression.py in __init__(self, endog, exog, var_type, reg_type, bw, ckertype, okertype, ukertype, defaults)
#     107         self.k_vars = len(self.var_type)
#     108         self.endog = _adjust_shape(endog, 1)
# --> 109         self.exog = _adjust_shape(exog, self.k_vars)
#     110         self.data = np.column_stack((self.endog, self.exog))
#     111         self.nobs = np.shape(self.exog)[0]
#
# ~/apps/anaconda3/lib/python3.8/site-packages/statsmodels/nonparametric/_kernel_base.py in _adjust_shape(dat, k_vars)
# ...

# %%
y
# Out:
# array([ 0.03682072, -0.51837748, -0.80486072,  0.35565589,  0.43706787,
#         0.31448538,  0.92650686,  0.71093496, -0.90122955,  0.92609721,
#         0.51060942, -0.07307742, -0.60469637, -0.74669157, -0.99955489,
#        -0.88627461, -0.91690846, -0.04052274, -0.13759876,  0.96273407,
#        -0.74538129, -0.60334638,  0.39295015,  0.99210414, -0.25137727,
#        -0.94552187, -0.73866794,  0.96101811, -0.98377391, -0.40052448,
#         0.97500057, -0.73858569,  0.30986876, -0.99257739, -0.99911088,
#         0.80895247,  0.99853958, -0.6821246 ,  0.90294559,  0.87587833])
