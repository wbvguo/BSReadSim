# %%
import os

# %%
path = "/home/wbguo/iproject/BSReadSim/temp/outdir/"

# %%
try:
    os.makedirs(path, exist_ok = False)
    print("Directory created successfully")
except OSError as error:
    print("Directory can not be created")
# Out:
# Directory can not be created
