# %% [markdown]
# ## Visual Python Upgrade
# NOTE:
# - Refresh your web browser to start a new version.
# - Save VP Note before refreshing the page.

# %%
# Visual Python
# !pip install visualpython --upgrade
# Out:
# Collecting visualpython
#   Downloading visualpython-2.3.0-py3-none-any.whl (15.0 MB)
#      |████████████████████████████████| 15.0 MB 3.6 MB/s eta 0:00:01
# Installing collected packages: visualpython
#   Attempting uninstall: visualpython
#     Found existing installation: visualpython 2.2.12
#     Uninstalling visualpython-2.2.12:
#       Successfully uninstalled visualpython-2.2.12
# Successfully installed visualpython-2.3.0

# %%
# Visual Python
# !visualpy install
# Out:
# Package install command: pip
# ============================================================================================
# Already exists Visual Python.
# ============================================================================================
# Disabling notebook extension visualpython/visualpython...
#       - Validating: OK
# ============================================================================================
# Remove Visual Python Directories.
# Target Dir :  /home/wbguo/.local/share/jupyter/nbextensions
# ============================================================================================
# Copy visualpyhthon extension files ...
# --------------------------------------------------------------------------------------------
# Source Dir :  /home/wbguo/.local/lib/python3.8/site-packages/visualpython
# Target Dir :  /home/wbguo/.local/share/jupyter/nbextensions/visualpython
# ============================================================================================
# Enabling notebook extension visualpython/visualpython...
#       - Validating: OK
