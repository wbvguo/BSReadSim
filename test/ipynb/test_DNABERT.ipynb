# %%
import sys

module_path = "/home/wbguo/iproject/BSReadSim/test/code/DNABERT/examples/"
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
import torch
from transformers import BertModel, BertConfig, DNATokenizer
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipykernel_1825907/676584837.py in <module>
#       1 import torch
# ----> 2 from transformers import BertModel, BertConfig, DNATokenizer
#
# ImportError: cannot import name 'DNATokenizer' from 'transformers' (/home/wbguo/.local/lib/python3.8/site-packages/transformers/__init__.py)

# %%
# need to run under the dnabert env

# %%
dir_to_pretrained_model = "/u/home/w/wbguo/project-pellegrini/BS_genotype/data/code/5-new-12w-0/pytorch_model.bin"
config = BertConfig.from_pretrained('https://raw.githubusercontent.com/jerryji1993/DNABERT/master/src/transformers/dnabert-config/bert-config-5/config.json')
tokenizer = DNATokenizer.from_pretrained('dna5')
model = BertModel.from_pretrained(dir_to_pretrained_model, config=config)
