# %%
import sys
sys.path.append('../../Simulate/')
import importlib

from StreamMethDB import StreamMethDB

# %%
working_path = "/home/wbguo/iproject/BSReadSim/test/"
outdir = working_path + "outdir/"

# %%
x = StreamMethDB(outdir=outdir)
x.create_outdir()

# %%
x.check_outdir()

# %%
from UtilityFunctions import get_htsim_path

# %%
import os

# %%
import random

# %%
random.choice([[0, 1], [1,0]])
# Out:
# [1, 0]

# %%
for i in range(2):
    print(i)
# Out:
# 0
# 1
